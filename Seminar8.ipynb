# %%
import pandas as pd
df = pd.read_excel(r'C:\Users\Dell\Documents\DBP221\ariuicca.xlsx')
df
# Out:
#              Order ID     Order Date  Customer ID         Segment  \
# 0   'CA-2016-152156',  '11.08.2016',  'EB-13930',      Хувь хүн',
# 1   'CA-2016-152156',  '11.08.2016',  'EB-13930',     'Хувь хүн',
# 2   'CA-2016-138688',            NaN          NaN  'Байгууллага',
# 3   'US-2015-108966',            NaN          NaN     'Хувь хүн',
# 4   'US-2015-108966',  '10.11.2015',  'JO-15550',     'Хувь хүн',
# ..                ...            ...          ...             ...
# 95  'US-2017-109484',  '11.06.2017',  'JR-15700',       'Гишүүн',
# 96  'CA-2017-161018',  '11.09.2017',  'AJ-10945',       'Гишүүн',
# 97  'CA-2017-157833',  '06.17.2017',  'BM-11575',     'Хувь хүн',
# 98  'CA-2016-149223',  '09.06.2016',  'CV-12805',  'Байгууллага',
# 99  'CA-2016-158568',  '08.29.2016',  'DK-12835',       'Гишүүн',
#
#           Region                            Category  \
# 0    'Баянзүрх',                   'Чихэр, печенье',
# 1    'Баянзүрх',           'OO ийн цаас, сальфетка',
# ...

# %%
df.isnull()
# Out:
#     Order ID  Order Date  Customer ID  Segment  Region  Category  \
# 0      False       False        False    False   False     False
# 1      False       False        False    False   False     False
# 2      False        True         True    False   False     False
# 3      False        True         True    False   False     False
# 4      False       False        False    False   False     False
# ..       ...         ...          ...      ...     ...       ...
# 95     False       False        False    False   False     False
# 96     False       False        False    False   False     False
# 97     False       False        False    False   False     False
# 98     False       False        False    False   False     False
# 99     False       False        False    False   False     False
#
#     Product Name  Price  Quantity  Discount  Sales
# 0          False  False     False     False  False
# 1          False  False     False     False  False
# ...

# %%
df.fillna('хоосон')
# Out:
#              Order ID     Order Date  Customer ID         Segment  \
# 0   'CA-2016-152156',  '11.08.2016',  'EB-13930',      Хувь хүн',
# 1   'CA-2016-152156',  '11.08.2016',  'EB-13930',     'Хувь хүн',
# 2   'CA-2016-138688',         хоосон       хоосон  'Байгууллага',
# 3   'US-2015-108966',         хоосон       хоосон     'Хувь хүн',
# 4   'US-2015-108966',  '10.11.2015',  'JO-15550',     'Хувь хүн',
# ..                ...            ...          ...             ...
# 95  'US-2017-109484',  '11.06.2017',  'JR-15700',       'Гишүүн',
# 96  'CA-2017-161018',  '11.09.2017',  'AJ-10945',       'Гишүүн',
# 97  'CA-2017-157833',  '06.17.2017',  'BM-11575',     'Хувь хүн',
# 98  'CA-2016-149223',  '09.06.2016',  'CV-12805',  'Байгууллага',
# 99  'CA-2016-158568',  '08.29.2016',  'DK-12835',       'Гишүүн',
#
#           Region                            Category  \
# 0    'Баянзүрх',                   'Чихэр, печенье',
# 1    'Баянзүрх',           'OO ийн цаас, сальфетка',
# ...

# %%
df.dropna()
# Out:
#              Order ID     Order Date  Customer ID         Segment  \
# 0   'CA-2016-152156',  '11.08.2016',  'EB-13930',      Хувь хүн',
# 1   'CA-2016-152156',  '11.08.2016',  'EB-13930',     'Хувь хүн',
# 4   'US-2015-108966',  '10.11.2015',  'JO-15550',     'Хувь хүн',
# 5   'CA-2014-115812',  '06.09.2014',  'RH-19600',     'Хувь хүн',
# 6   'CA-2014-115812',  '06.09.2014',  'RH-19600',     'Хувь хүн',
# ..                ...            ...          ...             ...
# 95  'US-2017-109484',  '11.06.2017',  'JR-15700',       'Гишүүн',
# 96  'CA-2017-161018',  '11.09.2017',  'AJ-10945',       'Гишүүн',
# 97  'CA-2017-157833',  '06.17.2017',  'BM-11575',     'Хувь хүн',
# 98  'CA-2016-149223',  '09.06.2016',  'CV-12805',  'Байгууллага',
# 99  'CA-2016-158568',  '08.29.2016',  'DK-12835',       'Гишүүн',
#
#           Region                            Category             Product Name  \
# 0    'Баянзүрх',                   'Чихэр, печенье',    'Shokolinsen 250 гр',
# ...

# %%
df.dropna(axis = 1)
# Out:
#              Order ID         Segment    Price Quantity Discount     Sales
# 0   'CA-2016-152156',      Хувь хүн',  '3300',     '2',     '0',   '6600',
# 1   'CA-2016-152156',     'Хувь хүн',   '500',     '3',     '0',   '1500',
# 2   'CA-2016-138688',  'Байгууллага',  '3100',     '2',     '0',   '6200',
# 3   'US-2015-108966',     'Хувь хүн',  '2800',     '5',     '0',  '14000',
# 4   'US-2015-108966',     'Хувь хүн',  '1150',     '2',     '0',   '2300',
# ..                ...             ...      ...      ...      ...       ...
# 95  'US-2017-109484',       'Гишүүн',  '3300',     '1',  '0.03',   '3201',
# 96  'CA-2017-161018',       'Гишүүн',  '2300',     '7',  '0.03',  '15617',
# 97  'CA-2017-157833',     'Хувь хүн',   '500',     '3',     '0',   '1500',
# 98  'CA-2016-149223',  'Байгууллага',  '2000',     '6',     '0',  '12000',
# 99  'CA-2016-158568',       'Гишүүн',  '1800',     '7',  '0.03',  '12222',
#
# [100 rows x 6 columns]
