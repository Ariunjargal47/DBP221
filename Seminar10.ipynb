# %%
#1
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
fig = plt.figure()
ax = plt.axes()
x = np.arange(0,10)
y = x*2
z = x**2
plt.plot(x,y)
print(plt.plot)
# Out:
# <function plot at 0x000001F0ACE7E8B0>

# %%
#2
plt.plot(x,y,color = 'orange')
print(plt.plot)
# Out:
# <function plot at 0x000001F0ACE7E8B0>

# %%
#3
plt.plot(x,y, '--b')
print(plt.plot)
# Out:
# <function plot at 0x000001F0ACE7E8B0>

# %%
#3_1
plt.plot(x,z, color = 'red')
print(plt.plot)
# Out:
# <function plot at 0x000001F0ACE7E8B0>
